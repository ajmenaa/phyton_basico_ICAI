# %% [markdown]
# # Entradas y salidas

# %%
import numpy as np
import pandas as pd

# Definimos un dataframe con datos de ejemplos
df = pd.DataFrame(np.random.randn(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0 -0.181572  1.814426  1.254914  2.743340 -0.460467
# 1  0.193459 -0.761585  0.352832  0.313536 -1.743063
# 2 -1.666960 -1.025956 -2.174590 -0.279311  1.292355
# 3  1.043291 -0.544594  1.412623 -0.484975  0.095446
# 4 -2.911215  0.176966  0.422896  0.209117  1.270135
# 5 -0.037873 -0.135220  1.729355  0.795466  0.406090
# 6  0.697160 -0.912364  0.865581  0.447645 -0.174919
# 7 -1.038530  0.680340  0.374397 -0.678747  0.108849
# 8 -0.180947  0.070051  0.736315  0.674430 -0.059566
# 9  0.074489  1.733110 -1.282267 -0.108710 -0.487285

# %% [markdown]
# ## CSV
#
# ### Guardar a CSV

# %%
df.to_csv('datos.csv', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde CSV

# %%
df = pd.read_csv('datos.csv')

df
# Out:
#           A         B         C         D         E
# 0 -0.181572  1.814426  1.254914  2.743340 -0.460467
# 1  0.193459 -0.761585  0.352832  0.313536 -1.743063
# 2 -1.666960 -1.025956 -2.174590 -0.279311  1.292355
# 3  1.043291 -0.544594  1.412623 -0.484975  0.095446
# 4 -2.911215  0.176966  0.422896  0.209117  1.270135
# 5 -0.037873 -0.135220  1.729355  0.795466  0.406090
# 6  0.697160 -0.912364  0.865581  0.447645 -0.174919
# 7 -1.038530  0.680340  0.374397 -0.678747  0.108849
# 8 -0.180947  0.070051  0.736315  0.674430 -0.059566
# 9  0.074489  1.733110 -1.282267 -0.108710 -0.487285

# %% [markdown]
# ## JSON
#
# ### Guardar a JSON

# %%
df.to_json('datos.json')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde JSON

# %%
df = pd.read_json('datos.json')

df
# Out:
#           A         B         C         D         E
# 0 -0.181572  1.814426  1.254914  2.743340 -0.460467
# 1  0.193459 -0.761585  0.352832  0.313536 -1.743063
# 2 -1.666960 -1.025956 -2.174590 -0.279311  1.292355
# 3  1.043291 -0.544594  1.412623 -0.484975  0.095446
# 4 -2.911215  0.176966  0.422896  0.209117  1.270135
# 5 -0.037873 -0.135220  1.729355  0.795466  0.406090
# 6  0.697160 -0.912364  0.865581  0.447645 -0.174919
# 7 -1.038530  0.680340  0.374397 -0.678747  0.108849
# 8 -0.180947  0.070051  0.736315  0.674430 -0.059566
# 9  0.074489  1.733110 -1.282267 -0.108710 -0.487285

# %% [markdown]
# ## Excel
#
# Necesitamos instalar el módulo `openpyxl` para generar y leer este formato:
#
#     pip install openpyxl

# %%
# !pip install openpyxl

# %% [markdown]
# ### Guardar a Excel

# %%
df.to_excel('datos.xlsx', sheet_name='Sheet1', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde Excel

# %%
df = pd.read_excel('datos.xlsx', sheet_name='Sheet1')

df
# Out:
#           A         B         C         D         E
# 0 -0.181572  1.814426  1.254914  2.743340 -0.460467
# 1  0.193459 -0.761585  0.352832  0.313536 -1.743063
# 2 -1.666960 -1.025956 -2.174590 -0.279311  1.292355
# 3  1.043291 -0.544594  1.412623 -0.484975  0.095446
# 4 -2.911215  0.176966  0.422896  0.209117  1.270135
# 5 -0.037873 -0.135220  1.729355  0.795466  0.406090
# 6  0.697160 -0.912364  0.865581  0.447645 -0.174919
# 7 -1.038530  0.680340  0.374397 -0.678747  0.108849
# 8 -0.180947  0.070051  0.736315  0.674430 -0.059566
# 9  0.074489  1.733110 -1.282267 -0.108710 -0.487285

# %% [markdown]
# Con `Matplotlib`, que aprenderemos en la próxima sección, podemos graficar estos resultados fácilmente:

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10,5

fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")

# %% [markdown]
# La práctica hace el maestro, os animo a hacer vuestras propias pruebas y googlear cualquier cosa que se os ocurra para aprender mucho más.
