# %% [markdown]
# # Entradas y salidas

# %%
import numpy as np
import pandas as pd

# Definimos un dataframe con datos de ejemplos
df = pd.DataFrame(np.random.randn(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0 -1.474013  0.075468  0.221508  0.304471  1.084263
# 1 -0.182198 -0.954649  0.903242  1.548281 -0.605651
# 2  2.595349  0.432744 -1.255182  0.399192 -0.503725
# 3 -0.099630 -2.198517  1.714157 -0.367705  0.684171
# 4  0.380816  0.261055 -1.076073 -0.005113  1.219943
# 5  0.445983 -2.099788 -0.509316  0.092033 -0.618860
# 6 -0.653650  0.800586  0.303052 -0.337886  1.188215
# 7  0.483870 -0.106534 -1.374734  1.195700  0.073601
# 8  0.493441  0.359159  1.239514  0.294604 -2.022496
# 9 -1.512533 -0.433724  0.045268  0.591847  2.414420

# %% [markdown]
# ## CSV
#
# ### Guardar a CSV

# %%
df.to_csv('datos.csv', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde CSV

# %%
df = pd.read_csv('datos.csv')

df
# Out:
#           A         B         C         D         E
# 0 -1.474013  0.075468  0.221508  0.304471  1.084263
# 1 -0.182198 -0.954649  0.903242  1.548281 -0.605651
# 2  2.595349  0.432744 -1.255182  0.399192 -0.503725
# 3 -0.099630 -2.198517  1.714157 -0.367705  0.684171
# 4  0.380816  0.261055 -1.076073 -0.005113  1.219943
# 5  0.445983 -2.099788 -0.509316  0.092033 -0.618860
# 6 -0.653650  0.800586  0.303052 -0.337886  1.188215
# 7  0.483870 -0.106534 -1.374734  1.195700  0.073601
# 8  0.493441  0.359159  1.239514  0.294604 -2.022496
# 9 -1.512533 -0.433724  0.045268  0.591847  2.414420

# %% [markdown]
# ## JSON
#
# ### Guardar a JSON

# %%
df.to_json('datos.json')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde JSON

# %%
df = pd.read_json('datos.json')

df
# Out:
#           A         B         C         D         E
# 0 -1.474013  0.075468  0.221508  0.304471  1.084263
# 1 -0.182198 -0.954649  0.903242  1.548281 -0.605651
# 2  2.595349  0.432744 -1.255182  0.399192 -0.503725
# 3 -0.099630 -2.198517  1.714157 -0.367705  0.684171
# 4  0.380816  0.261055 -1.076073 -0.005113  1.219943
# 5  0.445983 -2.099788 -0.509316  0.092033 -0.618860
# 6 -0.653650  0.800586  0.303052 -0.337886  1.188215
# 7  0.483870 -0.106534 -1.374734  1.195700  0.073601
# 8  0.493441  0.359159  1.239514  0.294604 -2.022496
# 9 -1.512533 -0.433724  0.045268  0.591847  2.414420

# %% [markdown]
# ## Excel
#
# Necesitamos instalar el módulo `openpyxl` para generar y leer este formato:
#
#     pip install openpyxl

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.0 kB 435.7 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/250.0 kB 393.8 kB/s eta 0:00:01
#    ----------------- -------------------- 112.6/250.0 kB 819.2 kB/s eta 0:00:01
#    ------------------------------- -------- 194.6/250.0 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 250.0/250.0 kB 1.1 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %% [markdown]
# ### Guardar a Excel

# %%
df.to_excel('datos.xlsx', sheet_name='Sheet1', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde Excel

# %%
df = pd.read_excel('datos.xlsx', sheet_name='Sheet1')

df
# Out:
#           A         B         C         D         E
# 0 -1.474013  0.075468  0.221508  0.304471  1.084263
# 1 -0.182198 -0.954649  0.903242  1.548281 -0.605651
# 2  2.595349  0.432744 -1.255182  0.399192 -0.503725
# 3 -0.099630 -2.198517  1.714157 -0.367705  0.684171
# 4  0.380816  0.261055 -1.076073 -0.005113  1.219943
# 5  0.445983 -2.099788 -0.509316  0.092033 -0.618860
# 6 -0.653650  0.800586  0.303052 -0.337886  1.188215
# 7  0.483870 -0.106534 -1.374734  1.195700  0.073601
# 8  0.493441  0.359159  1.239514  0.294604 -2.022496
# 9 -1.512533 -0.433724  0.045268  0.591847  2.414420

# %% [markdown]
# Con `Matplotlib`, que aprenderemos en la próxima sección, podemos graficar estos resultados fácilmente:

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10,5

fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 import matplotlib.pyplot as plt
#       2 plt.rcParams["figure.figsize"] = 10,5
# ----> 4 fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
#
# NameError: name 'fertility_rate' is not defined

# %% [markdown]
# La práctica hace el maestro, os animo a hacer vuestras propias pruebas y googlear cualquier cosa que se os ocurra para aprender mucho más.
